# %% [markdown]
# # Trabalho Final - Metagenômica grupo 1
#
#
#
# *    Julia Beltramini
# *    Kaira Cristina Peralis Tomaz
# *    Leonardo V. Azevedo
# *    Mélcar Collodetti
# *    Sara Reis
# *    Victor Aldair

# %% [markdown]
# # Descrição clínica do paciente:
# Paciente com síndrome respiratória aguda com uso recente do antibiótico Azitromicina e do fármaco Ivermectina.

# %% [markdown]
# # Parte 1 - Organização do espaço de trabalho

# %% [markdown]
# ###Remoção da pasta sample_data para limpeza do espaço de trabalho

# %%
# Remove a pasta sample_data porque ela vem porpadrão do Google Colabs e não é necessária
! rm -rf sample_data/

# %% [markdown]
# ###Conexão do Google Drive
# Será nosso repositório persistente de dados para não ter que recomeçar do zero as anotações.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Todos os membros do grupo criaram um alias em seus próprios drives de mesmo nome ("metagenomica") apontando para a pasta compartilhada que consolida os arquivos. Essa será a pasta base do trabalho

# %%
PACIENTE_S9_R1 = "https://aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com/TCC-metagenomica/patient_joao_METAGENOMICA_S9_R1_001.fastq.gz"
PACIENTE_S9_R2 = "https://aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com/TCC-metagenomica/patient_joao_METAGENOMICA_S9_R2_001.fastq.gz"

# %% [markdown]
# # Parte 2 - Configurar o ambiente para execução do pipeline
# Nesta etapa, vamos criar um ambiente conda e instalar as ferramentas que serão utilizadas no pipeline

# %%
# %%bash
# # Instala o gerenciador de envs Conda
# wget "https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-$(uname)-$(uname -m).sh"
# bash Miniforge3-$(uname)-$(uname -m).sh -b
# Out:
# PREFIX=/root/miniforge3
# Unpacking payload ...
# Extracting _libgcc_mutex-0.1-conda_forge.tar.bz2
# Extracting ca-certificates-2023.11.17-hbcca054_0.conda
# Extracting ld_impl_linux-64-2.40-h41732ed_0.conda
# Extracting libstdcxx-ng-13.2.0-h7e041cc_3.conda
# Extracting pybind11-abi-4-hd8ed1ab_3.tar.bz2
# Extracting python_abi-3.10-4_cp310.conda
# Extracting tzdata-2023c-h71feb2d_0.conda
# Extracting libgomp-13.2.0-h807b86a_3.conda
# Extracting _openmp_mutex-4.5-2_gnu.tar.bz2
# Extracting libgcc-ng-13.2.0-h807b86a_3.conda
# Extracting bzip2-1.0.8-hd590300_5.conda
# Extracting c-ares-1.24.0-hd590300_0.conda
# Extracting fmt-10.1.1-h00ab1b0_1.conda
# Extracting icu-73.2-h59595ed_0.conda
# Extracting keyutils-1.6.1-h166bdaf_0.tar.bz2
# Extracting libev-4.33-hd590300_2.conda
# Extracting libffi-3.4.2-h7f98852_5.tar.bz2
# Extracting libiconv-1.17-hd590300_2.conda
# Extracting libnsl-2.0.1-hd590300_0.conda
# Extracting libuuid-2.38.1-h0b41bf4_0.conda
# ...

# %%
import os
os.environ['PATH'] += ':/root/miniforge3/bin/'

# %%
# Instala todos os programas necessários
# !mamba install --channel bioconda \
  fastqc cutadapt kraken2 krona bwa \
  samtools spades --yes
# Out:
# Looking for: ['fastqc', 'cutadapt', 'kraken2', 'krona', 'bwa', 'samtools', 'spades']
#
# [+] 0.0s
# bioconda/linux-64 ..  ⣾  [+] 0.1s
# bioconda/linux-64 ..  ⣾  [+] 0.2s
# bioconda/linux-64 ..  ⣾  bioconda/linux-64 (check zst)
# [+] 0.0s
# bioconda/noarch (c..  ⣾  [+] 0.1s
# bioconda/noarch (c..  ⣾  bioconda/noarch (check zst)
# [+] 0.0s
# bioconda/linux-64  ⣾  [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.2s
# conda-forge/linux-64  15%
# conda-forge/noarch    10%
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.3s
# conda-forge/linux-64  20%
# conda-forge/noarch    34%
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.4s
# conda-forge/linux-64  25%
# conda-forge/noarch    46%
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.5s
# conda-forge/linux-64  30%
# conda-forge/noarch    46%
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.6s
# conda-forge/linux-64  30%
# ...

# %%
# testa se os programas foram instalados corretamente
# !samtools
# Out:
# Program: samtools (Tools for alignments in the SAM format)
# Version: 1.19.2 (using htslib 1.19.1)
#
# Usage:   samtools <command> [options]
#
# Commands:
#   -- Indexing
#      dict           create a sequence dictionary file
#      faidx          index/extract FASTA
#      fqidx          index/extract FASTQ
#      index          index alignment
#
#   -- Editing
#      calmd          recalculate MD/NM tags and '=' bases
#      fixmate        fix mate information
#      reheader       replace BAM header
#      targetcut      cut fosmid regions (for fosmid pool only)
#      addreplacerg   adds or replaces RG tags
#      markdup        mark duplicates
#      ampliconclip   clip oligos from the end of reads
#
#   -- File operations
#      collate        shuffle and group alignments by name
#      cat            concatenate BAMs
#      consensus      produce a consensus Pileup/FASTA/FASTQ
#      merge          merge sorted alignments
#      mpileup        multi-way pileup
# ...

# %%
# Faz download dos arquivos de taxid necessários no krona tools
# !ktUpdateTaxonomy.sh
# Out:
# Fetching taxdump.tar.gz...
#    Fetching checksum...
#    Checksum for taxdump.tar.gz matches server.
# Extracting taxonomy...
#
# Cleaning up...
#
# Finished.

# %% [markdown]
# # Download dos dados
# Download do banco utilizado pelo kraken2 para identificação taxonômica de organismos.

# %%
# !wget https://aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com/TCC-metagenomica/patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Out:
# --2024-02-06 17:13:47--  https://aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com/TCC-metagenomica/patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Resolving aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com (aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com)... 3.5.233.161, 16.12.0.50, 3.5.234.113, ...
# Connecting to aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com (aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com)|3.5.233.161|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1146111775 (1.1G) [application/x-gzip]
# Saving to: ‘patient_joao_METAGENOMICA_S9_R1_001.fastq.gz’
#
# patient_joao_METAGE 100%[===================>]   1.07G  17.8MB/s    in 64s
#
# 2024-02-06 17:14:52 (17.0 MB/s) - ‘patient_joao_METAGENOMICA_S9_R1_001.fastq.gz’ saved [1146111775/1146111775]

# %%
# !wget https://aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com/TCC-metagenomica/patient_joao_METAGENOMICA_S9_R2_001.fastq.gz
# Out:
# --2024-02-06 17:15:46--  https://aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com/TCC-metagenomica/patient_joao_METAGENOMICA_S9_R2_001.fastq.gz
# Resolving aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com (aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com)... 16.12.1.66, 3.5.232.130, 16.12.0.38, ...
# Connecting to aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com (aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com)|16.12.1.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1182978004 (1.1G) [application/x-gzip]
# Saving to: ‘patient_joao_METAGENOMICA_S9_R2_001.fastq.gz’
#
# patient_joao_METAGE 100%[===================>]   1.10G  16.9MB/s    in 5m 24s
#
# 2024-02-06 17:21:11 (3.48 MB/s) - ‘patient_joao_METAGENOMICA_S9_R2_001.fastq.gz’ saved [1182978004/1182978004]

# %%
# Download kraken2 database
# !wget https://genome-idx.s3.amazonaws.com/kraken/k2_standard_08gb_20231009.tar.gz
# Out:
# --2024-02-06 17:22:19--  https://genome-idx.s3.amazonaws.com/kraken/k2_standard_08gb_20231009.tar.gz
# Resolving genome-idx.s3.amazonaws.com (genome-idx.s3.amazonaws.com)... 3.5.25.220, 52.216.38.185, 52.217.72.60, ...
# Connecting to genome-idx.s3.amazonaws.com (genome-idx.s3.amazonaws.com)|3.5.25.220|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5902295843 (5.5G) [application/x-tar]
# Saving to: ‘k2_standard_08gb_20231009.tar.gz’
#
# k2_standard_08gb_20 100%[===================>]   5.50G  28.3MB/s    in 3m 26s
#
# 2024-02-06 17:25:46 (27.3 MB/s) - ‘k2_standard_08gb_20231009.tar.gz’ saved [5902295843/5902295843]

# %%
# Download genoma humano (hospedeiro) para remoção de contaminantes

# !wget http://igenomes.illumina.com.s3-website-us-east-1.amazonaws.com/Homo_sapiens/UCSC/hg38/Homo_sapiens_UCSC_hg38.tar.gz
# !tar -xf Homo_sapiens_UCSC_hg38.tar.gz
# Out:
# --2024-02-06 17:26:33--  http://igenomes.illumina.com.s3-website-us-east-1.amazonaws.com/Homo_sapiens/UCSC/hg38/Homo_sapiens_UCSC_hg38.tar.gz
# Resolving igenomes.illumina.com.s3-website-us-east-1.amazonaws.com (igenomes.illumina.com.s3-website-us-east-1.amazonaws.com)... 54.231.201.141, 16.182.42.5, 52.217.85.163, ...
# Connecting to igenomes.illumina.com.s3-website-us-east-1.amazonaws.com (igenomes.illumina.com.s3-website-us-east-1.amazonaws.com)|54.231.201.141|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16006984068 (15G) [application/x-tar]
# Saving to: ‘Homo_sapiens_UCSC_hg38.tar.gz’
#
# Homo_sapiens_UCSC_h 100%[===================>]  14.91G  37.8MB/s    in 6m 46s
#
# 2024-02-06 17:33:20 (37.6 MB/s) - ‘Homo_sapiens_UCSC_hg38.tar.gz’ saved [16006984068/16006984068]

# %%
HOST = '/content/Homo_sapiens/UCSC/hg38/Sequence/WholeGenomeFasta/genome.fa'

# %%
# Reorganizar os arquivos em uma estrutura intelegível de pastas
# !mkdir -p kraken2 kraken2-db fastq fastqc cutadapt host bwa
# !tar -xf k2_standard_08gb_20231009.tar.gz --directory kraken2-db/
# !rm k2_standard_08gb_20231009.tar.gz
# !rm Miniforge3-Linux-x86_64.sh
# !mv /content/Homo_sapiens/UCSC/hg38/Sequence/WholeGenomeFasta/genome.fa host/
HOST = 'genome.fa'

# %%
# !mv /content/patient_joao_METAGENOMICA_S9_R1_001.fastq.gz /content/fastq

# %%
# !mv /content/patient_joao_METAGENOMICA_S9_R2_001.fastq.gz /content/fastq

# %%
# Coletar nome da amostra em uma variável
temp = !basename fastq/*_R1_* _R1_001.fastq.gz
SAMPLE = temp[0]

# %%
# !echo {SAMPLE} {HOST}
# Out:
# patient_joao_METAGENOMICA_S9 genome.fa

# %% [markdown]
# # Controle de qualidade e limpeza das sequências
# Nesta etapa, vamos gerar um report de qualidade para os dados de sequenciamento da amostra e com base nele, vamos proceder com algumas limpezas (filtragem e trimagem).

# %%
# Gerar relatórios de qualidade do sequenciamento com fastqc
# !fastqc fastq/{SAMPLE}_R1_001.fastq.gz \
  fastq/{SAMPLE}_R2_001.fastq.gz \
  -o fastqc/
# Out:
# application/gzip
# application/gzip
# Started analysis of patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 5% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 10% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 15% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 20% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 25% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 30% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 35% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 40% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 45% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 50% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 55% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# Approx 60% complete for patient_joao_METAGENOMICA_S9_R1_001.fastq.gz
# ...

# %%
# Filtragem e trimagem das sequências com cutadapt
# !cutadapt -u 5 -U 5 -u -9 -U -9 -m 50  \
  -o cutadapt/{SAMPLE}_cleaned_R1.fastq.gz \
  -p cutadapt/{SAMPLE}_cleaned_R2.fastq.gz \
  fastq/{SAMPLE}_R1_001.fastq.gz \
  fastq/{SAMPLE}_R2_001.fastq.gz > cutadapt/summary_cutadapt.txt
# Out:
# Done           00:15:07    11,635,783 reads @  78.0 µs/read;   0.77 M reads/minute

# %% [markdown]
# # Remover contaminantes do hospedeiro
# Nesta etapa, precisamos pegar as sequências limpas na etapa anterior e proceder com o mapeamento no genoma de referência humano. Dessa forma, poderemos remover estas sequências que mapeias contra o genoma humano e ficar com apenas o que interessa para as demais etapas.

# %%
# Indexar a referência
# !bwa index host/{HOST}
# Out:
# [bwa_index] Pack FASTA... 36.72 sec
# [bwa_index] Construct BWT for the packed sequence...
# [BWTIncCreate] textLength=6199845082, availableWord=448243540
# [BWTIncConstructFromPacked] 10 iterations done. 99999994 characters processed.
# [BWTIncConstructFromPacked] 20 iterations done. 199999994 characters processed.
# [BWTIncConstructFromPacked] 30 iterations done. 299999994 characters processed.
# [BWTIncConstructFromPacked] 40 iterations done. 399999994 characters processed.
# [BWTIncConstructFromPacked] 50 iterations done. 499999994 characters processed.
# [BWTIncConstructFromPacked] 60 iterations done. 599999994 characters processed.
# [BWTIncConstructFromPacked] 70 iterations done. 699999994 characters processed.
# [BWTIncConstructFromPacked] 80 iterations done. 799999994 characters processed.
# [BWTIncConstructFromPacked] 90 iterations done. 899999994 characters processed.
# [BWTIncConstructFromPacked] 100 iterations done. 999999994 characters processed.
# ...

# %%
# Proceder com o alinhamento contra o genoma completo humano
# !bwa mem host/{HOST} \
  cutadapt/{SAMPLE}_cleaned_R1.fastq.gz \
  cutadapt/{SAMPLE}_cleaned_R2.fastq.gz \
  | samtools view -b > bwa/{SAMPLE}_mapped_host.bam
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 75728 sequences (10000004 bp)...
# [M::process] read 75840 sequences (10000255 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (3, 12781, 11, 2)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (173, 230, 285)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 509)
# [M::mem_pestat] mean and std.dev: (230.24, 81.48)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 621)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (130, 166, 197)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 331)
# [M::mem_pestat] mean and std.dev: (155.00, 59.62)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 398)
# ...

# %%
# Gerar BAM de não mapeados
# !samtools view -u -f 12 \
  -b bwa/{SAMPLE}_mapped_host.bam \
  | samtools sort -n > bwa/{SAMPLE}_unmapped_host.bam
# Out:
# [bam_sort_core] merging from 5 files and 1 in-memory blocks...

# %%
# Gerar relatório com os counts de reads mapeados em humano
# !samtools flagstat bwa/{SAMPLE}_mapped_host.bam \
  > bwa/{SAMPLE}_mapped_host_flagstat.txt

# %%
# Gerar FASTQ de reads não mapeados
# !samtools fastq bwa/{SAMPLE}_unmapped_host.bam \
  -1 bwa/{SAMPLE}_unmapped_host_R1.fastq \
  -2 bwa/{SAMPLE}_unmapped_host_R2.fastq
# Out:
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 12521652 reads

# %%
# !ls -lh bwa/
# Out:
# total 6.8G
# -rw-r--r-- 1 root root  2.2G Feb  6 23:44 patient_joao_METAGENOMICA_S9_mapped_host.bam
# -rw-r--r-- 1 root root   533 Feb  6 23:58 patient_joao_METAGENOMICA_S9_mapped_host_flagstat.txt
# -rw-r--r-- 1 root root 1015M Feb  6 23:57 patient_joao_METAGENOMICA_S9_unmapped_host.bam
# -rw-r--r-- 1 root root  1.9G Feb  6 23:59 patient_joao_METAGENOMICA_S9_unmapped_host_R1.fastq
# -rw-r--r-- 1 root root  1.9G Feb  6 23:59 patient_joao_METAGENOMICA_S9_unmapped_host_R2.fastq

# %% [markdown]
# # Identificação taxonômica
# Nesta etapa, vamos pegar os reads filtrados e não mapeados no hospedeiro para proceder com a identificação taxonômica dos reads. Esta etapa faz uma busca dos reads contra um banco de dados de organismos conhecidos, utilizando heurísticas específicas da ferramenta Kraken2.
# O kraken2 possui vários bancos disponíveis, com diferentes composições de genomas de organismos. Neste exemplo prático, escolhemos o banco **Standard 8GB** que é uma versão com Bacterias, Vírus, Archaea e Humano do NCBI Refseq. Os bancos do kraken2 geralmente utilizam muita memória RAM e isso pode ser uma limitação de execução em computadores mais simples. Todavia, uma versão que utiliza o máximo de 8GB de RAM é disponibilizada para computadores pequenos e esta versão está sendo utilizada nesta prática.
# Mais detalhes e download dos bancos [aqui](https://benlangmead.github.io/aws-indexes/k2).

# %%
# !kraken2 -db kraken2-db/ \
	--report kraken2/{SAMPLE}_kraken_report.txt \
  --output kraken2/{SAMPLE}_kraken2_NT.out \
	--minimum-base-quality 20 \
  --paired bwa/{SAMPLE}_unmapped_host_R1.fastq \
  bwa/{SAMPLE}_unmapped_host_R2.fastq
# Out:
# Loading database information... done.
# 6260826 sequences (1656.32 Mbp) processed in 105.288s (3567.8 Kseq/m, 943.88 Mbp/m).
#   1884470 sequences classified (30.10%)
#   4376356 sequences unclassified (69.90%)

# %%
# Gerar relatórios
# !ktImportTaxonomy kraken2/{SAMPLE}_kraken2_NT.out \
  -q 2 -t 3 \
  -o kraken2/{SAMPLE}_classification.html
# Out:
#    [ WARNING ]  Score column already in use; not reading scores.
# Loading taxonomy...
# Importing kraken2/patient_joao_METAGENOMICA_S9_kraken2_NT.out...
# Writing kraken2/patient_joao_METAGENOMICA_S9_classification.html...
#    [ WARNING ]  Too many query IDs to store in chart; storing supplemental files in
#                 'kraken2/patient_joao_METAGENOMICA_S9_classification.html.files'.

# %% [markdown]
# # Inspecionar resultados
# Nesta última etapa, cabe ao analista ou médico patologista/infectologista inspecionar os resultados gerados pelos relatórios de diversidade para identificar possíveis patógenos na amostra.
# É importante ressaltar que o resultado da identificação taxonômica gerado pelo kraken2 não deve ser levado em consideração unicamente. O processo de laudamente deve envolver uma etapa posterior de validação do achado, que poderia remover falso-positivos gerados pelo Kraken2 ou mesmo encontrar patógenos que não foram apontado pela identificação do Kraken2.

# %% [markdown]
# # Sugestão de etapa adicional de validação
# Como sugestões adicionais para validação, você poderia criar uma etapa de montagem dos reads em contigs (sequências maiores) e então realizar a mesma etapa de identificação taxônomica, só que tendo como input os contigs.fasta. Como dica, existe uma ferramenta excelente para esta finalidade chamada **Spades assembler**.
# Quais as possíveis vantagens deste procedimento comparado com a busca dos reads?

# %%
# Execuções vão aqui
#!spades.py \
#-1 bwa/{SAMPLE}_unmapped_host_R1.fastq \
#-2 bwa/{SAMPLE}_unmapped_host_R2.fastq \
#--meta -o Assembly/

# %%
# !wget https://aulas-pos-hiae-public-data.s3.sa-east-1.amazonaws.com/TCC-metagenomica/patient_joao_METAGENOMICA_contigs.fasta

# %%
# !mkdir Assembly

# %%
# !mv /content/patient_joao_METAGENOMICA_contigs.fasta  /content/Assembly

# %%
# Nova classificação para os contigs montados (sequencias mais longas)
# !kraken2 -db kraken2-db/ \
	--report kraken2/{SAMPLE}_kraken_report_contigs.txt \
  --output kraken2/{SAMPLE}_kraken2_NT_contigs.out \
  Assembly/contigs.fasta

# %%
# Gerar novo relatório, agora para os contigs
# !ktImportTaxonomy kraken2/{SAMPLE}_kraken2_NT_contigs.out \
  -q 2 -t 3 \
  -o kraken2/{SAMPLE}_classification_contigs.html
